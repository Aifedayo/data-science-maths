# %%
"""The goal is to predict prices per square area"""
# Out:
# 'The goal is to predict prices per square area'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import linear_model

# %%
# Load the prices in a dataframe
df = pd.read_csv("/home/akeemlag/Downloads/homeprices.csv")
df.head(10)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# Plot a scatter plot area vs price
plt.xlabel("area(sq ft)")
plt.ylabel("price(USD)")
plt.scatter(df.area, df.price, color='red', marker='+')

# %%
reg = linear_model.LinearRegression()

reg.fit(df[["area"]], df.price)
# Out:
# LinearRegression()

# %%
# Predict the price of home
reg.predict([[3300]])
# Out:
# /home/akeemlag/.local/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
"Use the same regression instance to predict the prices for a Series of Area"

df_area = pd.read_csv("/home/akeemlag/Downloads/areas.csv")
df_area.head()
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
price_pd = reg.predict(df_area)

# %%
df_area["price_predicted"] = price_pd

df_area
# Out:
#     area  price_predicted
# 0   1000     3.164041e+05
# 1   1500     3.842979e+05
# 2   2300     4.929281e+05
# 3   3540     6.613048e+05
# 4   4120     7.400616e+05
# 5   4560     7.998082e+05
# 6   5490     9.260908e+05
# 7   3460     6.504418e+05
# 8   4750     8.256079e+05
# 9   2300     4.929281e+05
# 10  9000     1.402705e+06
# 11  8600     1.348390e+06
# 12  7100     1.144709e+06

# %%
df_area.to_csv("/home/akeemlag/Downloads/prediction.csv", index=False)

# %%
plt.xlabel("area(sq ft)")
plt.ylabel("price(USD)")
plt.scatter(df.area, df.price, color='red', marker='+')
plt.plot(df.area, reg.predict(df[['area']]), color='blue');
